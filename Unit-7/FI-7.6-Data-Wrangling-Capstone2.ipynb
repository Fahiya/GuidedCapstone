# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os

# %% [markdown]
# ### Data Collection: Load Data from csv

# %%
df = pd.read_csv(r'C:\Users\fahiy\Documents\Springboard\Capstone\Unit-7\Unit7.6-Capstone2-BostonHosusing\train.csv')

# %%
df.head(6)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### Data Definition

# %% [markdown]
# #### Column Names

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# #### Data Types

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# #### Description of Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# #### Count of Unique Values

# %%
df.nunique()
# Out:
# Id               1460
# MSSubClass         15
# MSZoning            5
# LotFrontage       110
# LotArea          1073
#                  ...
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# SalePrice         663
# Length: 81, dtype: int64

# %% [markdown]
# #### Percent of Unique Values

# %%
df.nunique()/df.size*100
# Out:
# Id               1.234568
# MSSubClass       0.012684
# MSZoning         0.004228
# LotFrontage      0.093015
# LotArea          0.907323
#                    ...
# MoSold           0.010147
# YrSold           0.004228
# SaleType         0.007610
# SaleCondition    0.005074
# SalePrice        0.560629
# Length: 81, dtype: float64

# %% [markdown]
# #### Range of values per column

# %%
df.aggregate(['min','max'])
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# min     1          20  C (all)         21.0     1300   Grvl      IR1
# max  1460         190       RM        313.0   215245   Pave      Reg
#
#     LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# min         Bnk    AllPub    Corner  ...             0         0           0
# max         Lvl    NoSeWa    Inside  ...           552       508         480
#
#     PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# min        0       0      1    2006       COD        Abnorml      34900
# max      738   15500     12    2010        WD        Partial     755000
#
# [2 rows x 65 columns]

# %% [markdown]
# #### Statistics about the numerical columns

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %%
plt.figure(figsize=(40,15))
#plt.xticks(rotation='90')
sns.countplot(x='SalePrice', data=df)

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Handle the Missing and NA values

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# #### calculating percentage of missing data by features:

# %%
df_percentage = (df.isnull().sum() / len(df)) * 100

f, ax = plt.subplots(figsize=(15, 8))
plt.xticks(rotation='90')
sns.barplot(x=df_percentage.index, y=df_percentage)
plt.xlabel('Features', fontsize=15)
plt.ylabel('Percent of missing values', fontsize=15)
plt.title('Percent missing data by feature', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percent missing data by feature')

# %% [markdown]
# ##### The above figure shows the features 'PoolQC', 'MiscFeature', 'Alley', 'Fence' have many null values. The following heatmap shows the same thing.

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)

# %%
# We are trying to see how many features have missing values by taking a look at the percentage
nas=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)/len(df),columns = ['percent'])
pos = nas['percent'] > 0
nas[pos]
# Out:
#                percent
# PoolQC        0.995205
# MiscFeature   0.963014
# Alley         0.937671
# Fence         0.807534
# FireplaceQu   0.472603
# LotFrontage   0.177397
# GarageCond    0.055479
# GarageType    0.055479
# GarageYrBlt   0.055479
# GarageFinish  0.055479
# GarageQual    0.055479
# BsmtExposure  0.026027
# BsmtFinType2  0.026027
# BsmtFinType1  0.025342
# BsmtCond      0.025342
# BsmtQual      0.025342
# MasVnrArea    0.005479
# MasVnrType    0.005479
# Electrical    0.000685

# %% [markdown]
# ###### It looks like PoolQC and a few other  features have null values more than 80 percent so it might be tempting to drop the columns. But we will not be dropping them. We do isnull on the columns that have NaNs in them and create a new dataframe that has only the columns with NaN in it. And then we do .isnull() on each of them and that creates a two column dataframe that has nothing but True and False. That becomes our feature that we add. We can add these new columns back into our original dataframe and call them, say, LotArea_isnull and then we fillna() the original null columns with typical practice-> 0/mean/max/min, etc.

# %% [markdown]
# #### Numerical Variables

# %%
dfn = df._get_numeric_data() #We also found numeric data info when we did describe()
dfn.head(11)
# Out:
#     Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0    1          60         65.0     8450            7            5       2003
# 1    2          20         80.0     9600            6            8       1976
# 2    3          60         68.0    11250            7            5       2001
# 3    4          70         60.0     9550            7            5       1915
# 4    5          60         84.0    14260            8            5       2000
# 5    6          50         85.0    14115            5            5       1993
# 6    7          20         75.0    10084            8            5       2004
# 7    8          60          NaN    10382            7            6       1973
# 8    9          50         51.0     6120            7            5       1931
# 9   10         190         50.0     7420            5            6       1939
# 10  11          20         70.0    11200            5            5       1965
#
# ...

# %% [markdown]
# ##### Now that we have separated out our Numerical features, time to see how many numercial features have missing values

# %%
nas=pd.DataFrame(dfn.isnull().sum().sort_values(ascending=False)/len(dfn),columns = ['percent'])
pos = nas['percent'] > 0
nas[pos]
# Out:
#               percent
# LotFrontage  0.177397
# GarageYrBlt  0.055479
# MasVnrArea   0.005479

# %% [markdown]
# #### We can also check the heat map for dfn DataFrame

# %%
sns.heatmap(dfn.isnull(),yticklabels=False,cbar=False)

# %% [markdown]
# ##### It shows only three Numercial features have null values. So, we are adding the _isnull features for all three now per the discussion above

# %%
dfn['LotFrontaget_isnull'] = dfn['LotFrontage'].isnull()
dfn['GarageYrBlt_isnull'] = dfn['GarageYrBlt'].isnull()
dfn['MasVnrArea_isnull'] = dfn['MasVnrArea'].isnull()

# %%
#Creating a list of dfn.columns and adding the three extra columns in the list with append().
#Then checking if the feature numbers increased by three. 
features_added = list(dfn.columns)
features_added.append('LotFrontaget_isnull')
features_added.append('GarageYrBlt_isnull')
features_added.append('MasVnrArea_isnull')

# %%
dfn.shape # We shoule see three extra columns added to the existing 38 columns.
# Out:
# (1460, 41)

# %% [markdown]
# #### Now replacing the nulls with mean values. Generally, null for float values are replaced by mean, but we are not longer worried about what method we use, since we have added the extra features with isnull, we are just using mean.

# %%
# Creating a new dataframe after null value replacement
dfn_no_null = dfn.fillna(value=dfn.mean())

# %% [markdown]
# ### Check for Duplicated Rows

# %%
duplicateRowsDF=dfn[dfn.duplicated()]
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, LotFrontage, LotArea, OverallQual, OverallCond, YearBuilt, YearRemodAdd, MasVnrArea, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, TotRmsAbvGrd, Fireplaces, GarageYrBlt, GarageCars, GarageArea, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SalePrice, LotFrontaget_isnull, GarageYrBlt_isnull, MasVnrArea_isnull]
# Index: []
#
# [0 rows x 41 columns]

# %%
dfn.shape
# Out:
# (1460, 41)

# %% [markdown]
#   #### Checking the heat map after filling/ Handling the Null Values. The new DataFrame is "dfn_no_null"

# %%
sns.heatmap(dfn_no_null.isnull(),yticklabels=False,cbar=False) # We see no null in the heat map

# %%
dfn_no_null.to_csv('Wrangled_data.csv')

# %%
pwd
# Out:
# 'C:\\Users\\fahiy\\Documents\\Springboard\\Capstone\\Unit-7\\Unit7.6-Capstone2-BostonHosusing'
